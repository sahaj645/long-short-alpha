# %% [markdown]
# # 05 — Liquidity analysis
#
# Map tradable opportunity set at each AUM level given 10% participation cap.
#
# See docs/05_experimental_framework.docx for full protocol.

# %%
# Implementation pending.
