# %% [markdown]
# # 09 — Transaction cost analysis
#
# Calibrate impact-α from realized fills; decompose into spread/impact/borrow.
#
# See docs/05_experimental_framework.docx for full protocol.

# %%
# Implementation pending.
