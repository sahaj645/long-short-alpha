# %% [markdown]
# # 08 — Capacity analysis
#
# Net IR vs AUM curve; identify optimal AUM and committed-range viability.
#
# See docs/05_experimental_framework.docx for full protocol.

# %%
# Implementation pending.
