# %% [markdown]
# # 06 — Sector neutrality analysis
#
# Verify realized portfolio sector betas are zero; stress-test in rotation episodes.
#
# See docs/05_experimental_framework.docx for full protocol.

# %%
# Implementation pending.
